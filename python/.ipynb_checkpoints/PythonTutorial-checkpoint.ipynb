# %% [markdown]
# # BioE245: Introduction to Python
#
# In this tutorial, we will cover the basics of working with some important Python libraries that you will be using for your homework and projects.
#
# ## Importing necessary libraries
#
# First, we need to import the `numpy` library, which provides support for large, multi-dimensional arrays and matrices, along with a collection of mathematical functions to operate on these arrays. We will also import the `matplotlib` library to visualize the matrices.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Import the function we need to play the electrode movies
from utils import play_brain_movie

play_brain_movie(filename='cropped_brain.mp4')
# Out:
#     <video width=400 controls>
#           <source src="data:video/mp4;base64,..." type="video/mp4">
#     </video>

# %% [markdown]
# To use functions defined in the `utils` module, we need to import it as well.

# %%
from utils import load_data

# Load the ecog data
data = load_data()

# %%
data['ecog'].shape
# Out:
# (11, 278, 2)
